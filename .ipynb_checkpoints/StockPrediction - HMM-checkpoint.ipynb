# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from pomegranate import *
import matplotlib.pyplot as plt
from hmm_model import *
from sklearn import linear_model

# %%
symbols_list = ["AAL", "AAPC", "ABAX", "ABDC", "ABEO", "ABGB", "ABMD", "ABTL", "ABUS", "ACAD", "ACFC", "ACHC", "ACOR", "ACXM", "ADAT", "ADRU", "ADXS", "AEGR", "AETI", "AGEN", "AGYS", "AHGP", "AIMC", "AIMT", "AKRX", "AKTX", "ALKS", "ALLT", "ALOT", "ALQA", "ALXN", "AMBA", "AMCN", "AMCX", "AMDA", "AMIC", "AMKR", "AMRS", "AMSG", "ANDA", "APDNW", "APPF", "ARCI", "ARIA", "ARIS", "ARTX", "ASEI", "ASFI", "ASMB", "ASPS", "ASTI", "ASUR", "ATEC", "ATLC", "ATML", "ATSG", "AUDC", "AUMAU", "AVXL", "AXPWW", "BASI", "BBBY", "BBEP", "BBGI", "BBP", "BCBP", "BCOM", "BCOV", "BDBD", "BFIN", "BGFV", "BIB", "BIIB", "BIND", "BIOS", "BKEPP", "BLIN", "BLMN", "BLMT", "BLVD", "BLVDU", "BMRN", "BNFT", "BNSO", "BNTC", "BOBE", "BOKF", "BPFH", "BPFHP", "BPOPN", "BRCD", "BRCM", "BRKL", "BSRR", "BUFF", "BVA", "BVSN", "BVXV", "BWFG", "BYLK", "CADC", "CADTU", "CADTW", "CALI", "CARA", "CARB", "CATY", "CBAK", "CBFV", "CBIO", "CBMX", "CBNJ", "CBPO", "CCBG", "CCCR", "CCNE", "CCOI", "CDNA", "CDOR", "CDTI", "CECE", "CECO", "CERN", "CERS", "CETC", "CFGE", "CFNL", "CFO", "CGNX", "CHEF", "CHEK", "CHFC", "CHMA", "CHMG", "CHNR", "CHY", "CIFC", "CISG", "CIZ", "CIZN", "CLAC", "CLBH", "CLBS", "CLRB", "CLRBW", "CLUB", "CMCO", "CME", "CMFN", "CMRX", "CNFR", "CNLM", "CNMD", "COHR", "COHU", "COLB", "CORE", "COSI", "CPHC", "CPHR", "CPIX", "CRBP", "CRESY", "CRIS", "CRVL", "CRWS", "CSB", "CSOD", "CSX", "CTBI", "CTCM", "CTCT", "CTIC", "CTRN", "CTRP", "CTSH", "CUNB", "CVBF", "CVCO", "CVCY", "CVGI", "CVV", "CWBC", "CWST", "CXRX", "CYCC", "CYCCP", "CYTR", "CZFC", "CZR", "DBVT", "DCIX", "DENN", "DFVL", "DGICB", "DGRW", "DHXM", "DIOD", "DISCK", "DISH", "DMRC", "DOX", "DRAD", "DSCI", "DSKX", "DSWL", "DTRM", "DTUS", "DTYS", "DVAX", "DWTR", "DXCM", "DYAX", "DYNT", "DYSL", "EACQ", "EAGLU", "EBMT", "ECACU", "ECTE", "ECYT", "EDBI", "EEMA", "EGHT", "EGLE", "ELTK", "EMMS", "ENSG", "ENZN", "EPIX", "EQFN", "EQIX", "ESBK", "ESES", "ESIO", "ESRX", "EVAR", "EVEP", "EVOL", "EXAS", "EXTR", "EXXI", "EYEG", "FANG", "FBSS", "FCA", "FCAN", "FCBC", "FCCO", "FCCY", "FCLF", "FCVA", "FCVT", "FDEF", "FDML", "FEIC", "FEUZ", "FEYE", "FFBC", "FFBCW", "FFHL", "FGEN", "FHCO", "FIZZ", "FKO", "FKU", "FLAT", "FLDM", "FMB", "FMER", "FNBC",
", "QTNT", "RBCAA", "RCII", "RCKY", "RDIB", "RDUS", "REDF", "REGI", "REGN", "RELY", "RGSE", "RIBTW", "RICK", "RLJE", "RLOC", "RLOG", "RNET", "RNVA", "ROBO", "ROIC", "ROST", "RRD", "RTTR", "RUSHA", "RVLT", "RXII", "SAFM", "SALM", "SANW", "SBBX", "SBFGP", "SBRAP", "SBSI", "SBUX", "SCSS", "SCTY", "SCVL", "SEAC", "SEDG", "SENEB", "SGMO", "SGNL", "SGNT", "SGYP", "SGYPU", "SGYPW", "SHLO", "SHOS", "SIEB", "SIGM", "SIRI", "SIRO", "SKUL", "SKYS", "SLM", "SMLR", "SMMF", "SMRT", "SNC", "SNDK", "SNFCA", "SNHY", "SNSS", "SOCB", "SOFO", "SOHOL", "SOHU", "SOXX", "SPI", "SPLK", "SPNS", "SQI", "SRDX", "SSFN", "SSYS", "STKS", "STLY", "STRL", "STRZA", "SUNS", "SWSH", "SYMX", "SYNA", "SYNL", "SYRX", "SYUT", "SZMK", "SZYM", "TANH", "TBK", "TBRA", "TCBK", "TCFC", "TECD", "TFM", "TFSC", "TGLS", "THLD", "TINY", "TKAI", "TOPS", "TRCH", "TRIL", "TRNS", "TROVW", "TRS", "TRTL", "TSC", "TTEK", "TTGT", "TTPH", "TVIX", "TW", "UACL", "UBFO", "UCBA", "UDF", "UFPT", "UK", "ULTA", "ULTI", "ULTR", "UMBF", "UNAM", "UNIS", "UNTY", "USCR", "USLM", "UTIW", "VBND", "VCSH", "VGSH", "VIP", "VISN", "VMBS", "VNQI", "VONV", "VRA", "VRML", "VRTU", "VRTX", "VSTM", "VTVT", "VXUS", "VYGR", "WATT", "WBB", "WFD", "WGBS", "WHLM", "WHLR", "WIBC", "WIFI", "WILN", "WIN", "WKHS", "WMIH", "WRES", "WSBC", "WSCI", "WSFSL", "WSTG", "WVFC", "WWD", "XBIT", "XCRA", "XGTI", "XGTIW", "XLNX", "XNCR", "XRDC", "XXIA", "YHOO", "YLCO", "YY", "ZBIO", "ZBRA", "ZEUS", "ZGNX", "ZHNE", "ZINC", "ZLTQ", "ZN", "ZSAN"]

# %%
def normalize_data(data):
    n = len(data)
    X = np.ones(shape=(n, 2))
    X[:,0] = np.arange(n)

    Y = data.reshape(n, 1)
    lin_reg = linear_model.LinearRegression()
    lin_reg.fit(X, Y)

    coefs = np.array([lin_reg.coef_[0][0], lin_reg.intercept_[0]])
    
    offset_data = np.dot(X, coefs)
    data_normalized = data - offset_data
    return data_normalized, offset_data


def train(hmm_model, data_flow, fake=False):
    first = hmm_model.model.log_probability(data_flow)
    if not fake:
        hmm_model.train(data_flow)
    second = hmm_model.model.log_probability(data_flow)
    return first, second

def prepare_test_data(path, column="Open"):
    data_wrapper = DataWrapper(path, ',')
    data = np.array(data_wrapper.data["Open"])
    data_normalized, offset_data = normalize_data(data)

    data_flow = DataWrapper.get_data_flow(data_normalized)
    max_value = 5.0
    normalization_factor = 5.0/np.max(np.abs(data_flow))
    data_flow_normalized = data_flow * normalization_factor
    
    return data_flow_normalized

    
def split_data(data, test_size):
    data_train = data[:-test_size]
    data_test = data[-test_size:]
    return data_train, data_test


def invert_data_flow(data_flow):
    result = []
    last_value = 0
    for x in data_flow:
        last_value += x
        result.append(last_value)
    return np.array(result)

# %%
hmm_model = HmmModelWrapper()
hmm_model.load_from_json("model.json")
for symbol in symbols_list:
    path = "./data/{}.csv".format(symbol)
    data_flow_normalized = prepare_test_data(path)
    if len(data_flow_normalized) == 0:
        continue

    train_data_flow = np.array(data_flow_normalized)

    hmm_model = HmmModelWrapper()
    first, last = train(hmm_model, train_data_flow, True)    
    print symbol, first,last
# Out:
# AAL -5727.81302246 -5727.81302246
# AAPC -430.407104113 -430.407104113
# ABAX -9682.86123818 -9682.86123818
# ABDC -951.465373287 -951.465373287
# ABEO -20180.2640475 -20180.2640475
# ABGB -1260.04531616 -1260.04531616
# ABMD -16266.5645261 -16266.5645261
# ABTL -9568.97738377 -9568.97738377
# ABUS -4835.21572996 -4835.21572996
# ACAD -6611.26006127 -6611.26006127
# ACFC -6442.63558169 -6442.63558169
# ACHC -12473.6462795 -12473.6462795
# ACOR -5509.8402026 -5509.8402026
# ACXM -17884.67678 -17884.67678
# ADAT -11025.3183047 -11025.3183047
# ADRU -7546.97373314 -7546.97373314
# ADXS -5977.89694337 -5977.89694337
# AEGR -2955.72460092 -2955.72460092
# AETI -4909.95778378 -4909.95778378
# AGEN -9078.69124708 -9078.69124708
# AGYS -14638.5896445 -14638.5896445
# AHGP -5356.60353885 -5356.60353885
# AIMC -817.879090855 -817.879090855
# AIMT -262.624671432 -262.624671432
# AKRX -7660.32245291 -7660.32245291
# AKTX -1174.11804918 -1174.11804918
# ALKS -10663.4134661 -10663.4134661
# ...

# %%
hmm_model = HmmModelWrapper()
hmm_model.load_from_json("model.json")

symbol = "AMBA"
path = "./data/{}.csv".format(symbol)
data_wrapper = DataWrapper(path, ',')
data = np.array(data_wrapper.data["Open"])[:-10]
data_normalized, offset_data = normalize_data(data)

data_flow = DataWrapper.get_data_flow(data_normalized)
print len(data_flow)
data_train, data_test = split_data(data_flow, 200)

current = list(data_train)

print hmm_model.model.log_probability(current)
hmm_model.train(current)
print hmm_model.model.log_probability(current)
# Out:
# 815
# -2458.14046303
# -1392.55870286

# %%
prediction_value = 0
prediction_sum = 0
prediction = []


values = []
for x in data_test:
    hypothesis = []
    hypothesis_values = []
    for y in range(-10, 11):
        log_prob = hmm_model.model.log_probability(current+[y])

        hypothesis.append(log_prob)
        hypothesis_values.append((y, log_prob))

    h = dict(hypothesis_values)
    values.append((h[-1], h[0], h[1]))
    #prediction_value = 0
    #prediction_sum += prediction_value
    #prediction.append(prediction_sum)
    current.append(x)

avm1 = sorted(map(lambda x:x[0], values))
av0 = sorted(map(lambda x:x[1], values))
av1 = sorted(map(lambda x:x[2], values))
nvm1 = avm1[0] - avm1[-1]
nv0 = av0[0] - av0[-1]
nv1 = av1[0] - av1[-1]
    
prediction = []
prediction_value = 0

for vm1, v0, v1 in values:
    cvm1 = (vm1 - avm1[-1]) / nvm1
    cv0 = (v0 - av0[-1]) / nv0
    cv1 = (v1 - av1[-1]) / nv1
    m = min([cvm1, cv0, cv1])
    va = np.array([cvm1, cv0, cv1]) - m

    if va[2] > 0.002:
        prediction_value += 1
    elif va[1] > 0:
        prediction_value += 0
    elif va[0] > 0:
        prediction_value += -1
    else:
        prediction_value += 0
        
        
    prediction.append(prediction_value)
plt.plot(prediction)
plt.plot(invert_data_flow(data_test))
plt.show()
